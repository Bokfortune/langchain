# %%
from report_service import investment_report
from search import stock_search

investment_report("Apple Inc.", "AAPL")
# Out:
# {'company': 'Apple Inc.',
#  'basic_info': '|                   | Values               |\n|:------------------|:---------------------|\n| longName          | Apple Inc.           |\n| industry          | Consumer Electronics |\n| sector            | Technology           |\n| marketCap         | 2916513742848        |\n| sharesOutstanding | 14935799808          |',
# ...
